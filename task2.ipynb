# %% [markdown]
# # TASK 2 of Data Science and Bussiness Analyst Internship
#
# ### Prediction Using UnSupervised Learning
#
# ### Implemented by YAMINI NAGWANSHI

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from guietta import _, Gui, Quit
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('Iris.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
print(df.keys())
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
x = df.iloc[:,[0,1,2,3]].values
y = df['Species'].values


x
# Out:
# array([[  1. ,   5.1,   3.5,   1.4],
#        [  2. ,   4.9,   3. ,   1.4],
#        [  3. ,   4.7,   3.2,   1.3],
#        [  4. ,   4.6,   3.1,   1.5],
#        [  5. ,   5. ,   3.6,   1.4],
#        [  6. ,   5.4,   3.9,   1.7],
#        [  7. ,   4.6,   3.4,   1.4],
#        [  8. ,   5. ,   3.4,   1.5],
#        [  9. ,   4.4,   2.9,   1.4],
#        [ 10. ,   4.9,   3.1,   1.5],
#        [ 11. ,   5.4,   3.7,   1.5],
#        [ 12. ,   4.8,   3.4,   1.6],
#        [ 13. ,   4.8,   3. ,   1.4],
#        [ 14. ,   4.3,   3. ,   1.1],
#        [ 15. ,   5.8,   4. ,   1.2],
#        [ 16. ,   5.7,   4.4,   1.5],
#        [ 17. ,   5.4,   3.9,   1.3],
#        [ 18. ,   5.1,   3.5,   1.4],
#        [ 19. ,   5.7,   3.8,   1.7],
#        [ 20. ,   5.1,   3.8,   1.5],
#        [ 21. ,   5.4,   3.4,   1.7],
#        [ 22. ,   5.1,   3.7,   1.5],
#        [ 23. ,   4.6,   3.6,   1. ],
#        [ 24. ,   5.1,   3.3,   1.7],
#        [ 25. ,   4.8,   3.4,   1.9],
# ...

# %%
#Finding The Optimum Number of Clusters for K-means classification

wss = []    # within-cluster sum of square  

for i in range(1,11):
    
    # MODEL INSTANTIATED 
    kmeans = KMeans(n_clusters = i, init = 'k-means++' , max_iter =300, n_init = 10 , random_state = 0)
    kmeans.fit(x)
    wss.append(kmeans.inertia_)

# %%
#Plotting Result Onto Graph

plt.plot(range(1,11),ws)
plt.xlabel("Number of Clusters")
plt.ylabel("wss")
plt.show()

# %% [markdown]
# ### The location of a bend in the plot is generally considered as an indicator of the appropriate number of clusters.
#
# ## Therefore, Number of Cluster = 3

# %%
# Visualizing DATA 
 
sns.FacetGrid(df, hue="Species", palette="cubehelix", height=5).map(plt.scatter, "SepalLengthCm", "SepalWidthCm").add_legend()

# %%
print(y.reshape(-1,1))
# Out:
# [['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-versicolor']
#  ['Iris-versicolor']
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.pairplot(df.drop("Id", axis=1), hue="Species", palette="cubehelix", height=3)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
kmeans = KMeans(n_clusters = 3)
labels = kmeans.fit_predict(X_train,y_train)
labels
# Out:
# array([1, 1, 2, 1, 0, 0, 2, 2, 0, 0, 2, 2, 1, 2, 0, 1, 0, 2, 0, 1, 0, 2,
#        0, 0, 2, 2, 1, 2, 2, 0, 1, 0, 1, 2, 1, 0, 2, 2, 1, 1, 1, 0, 0, 0,
#        2, 0, 1, 2, 2, 0, 2, 1, 0, 2, 2, 1, 0, 1, 0, 0, 1, 0, 1, 0, 2, 2,
#        0, 1, 1, 0, 2, 1, 0, 1, 1, 0, 1, 1, 2, 1, 0, 0, 0, 1, 1, 0, 2, 1,
#        2, 1, 0, 2, 1, 2, 1, 1, 1, 2, 2, 2, 2, 0, 0, 2, 1, 0, 1, 0, 1, 2,
#        2, 0, 0, 2, 2, 0, 1, 2, 0, 2, 0, 2, 0, 1, 1, 1, 1, 1, 0, 2, 1, 0,
#        1, 1, 2])

# %%
y_pred = kmeans.fit_predict(X_test,y_test)
y_pred
# Out:
# array([1, 0, 1, 2, 2, 2, 0, 0, 2, 2, 0, 0, 0, 2, 1])
